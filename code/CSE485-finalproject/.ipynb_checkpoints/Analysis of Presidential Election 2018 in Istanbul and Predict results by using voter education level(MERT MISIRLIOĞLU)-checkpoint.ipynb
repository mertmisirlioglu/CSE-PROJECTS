# %% [markdown]
# # Title: Analysis of Presidential Election 2018 in Istanbul and Predict results by using voter education level.
#
# ## Author: Mert Mısırlıoğlu
#
# #### Date: 6.05.2019
#
# #### Data sources: https://biruni.tuik.gov.tr/secimdagitimapp/menuhalk.zul
#
# #### Summary (Abstract):
# I have two data one is presidential election results and other one is education level of voters. I analyzed two of them and concatenate to each other. After that I decided to estimate election results by  using voter education level data with sklearn. My aim is getting closer prediction to real results.

# %% [markdown]
# ## Introduction and Problem  Statement
#
# #### My first hypothesis is which is graduated as Ph.D , postgraduate or faculty voters are votes for Muharrem İnce, uneducated , primary school or middle school graduates are votes for Recep Tayyip Erdoğan.
# #### I made  predictions with using voter educational level data to estimate percentage of Recep Tayyip Erdoğan , Muharrem İnce and Meral Akşener. And my hypothesis is that my estimates have an mean square error of less than 0.25.

# %% [markdown]
# ## Data Description
# I use tüik database to reach data but when I extract datas to excel I had a issue so I convert xls file to csv by manuel.
# I used two csv file one of them is result of elections and other one is education level of voters. Sec.csv(which includes result of election) 5 kb , Ogr.csv(which includes education level of voters) 3 kb.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
secim = pd.read_csv("data/sec.csv")
ogr = pd.read_csv("data/ogr.csv")
secim
# Out:
#           İl           İlçe  Sandık_Sayısı  Kayıtlı_SeçmenSayısı  \
# 0   İstanbul         Adalar             36                 11967
# 1   İstanbul       Bakırköy            463                168450
# 2   İstanbul       Beşiktaş            394                140754
# 3   İstanbul         Beykoz            513                184234
# 4   İstanbul        Beyoğlu            475                170779
# 5   İstanbul        Çatalca            160                 53501
# 6   İstanbul     Eyüpsultan            752                273863
# 7   İstanbul          Fatih            794                283991
# 8   İstanbul  Gaziosmanpaşa            936                349260
# 9   İstanbul        Kadıköy            995                363413
# 10  İstanbul         Kartal            938                344826
# 11  İstanbul        Sarıyer            690                248940
# 12  İstanbul        Silivri            386                120995
# ...

# %%
secim.describe()
# Out:
#        Sandık_Sayısı  Kayıtlı_SeçmenSayısı  Oy_Kullanan_Seçmen_Sayısı  \
# count      39.000000             39.000000                  39.000000
# mean      739.102564         270761.179487              238580.000000
# std       360.313883         135080.800824              118246.004607
# min        36.000000          11967.000000               10535.000000
# 25%       476.000000         173598.000000              154372.500000
# 50%       690.000000         253892.000000              225906.000000
# 75%       941.000000         349824.000000              310007.000000
# max      1484.000000         549448.000000              474741.000000
#
#        Katılım_Yüzdesi  Geçerli_oy_sayısı  Geçerli_oy_sayı_yüzdesi  \
# count        39.000000          39.000000                39.000000
# mean         88.376923      234792.025641                98.387179
# std           1.888812      116364.321678                 0.327012
# ...

# %%
ogr
# Out:
#           il           ilçe  okuma_yazma_bilmeyen_sayisi  \
# 0   İstanbul         Adalar                          229
# 1   İstanbul       Bakırköy                         1530
# 2   İstanbul       Beşiktaş                         1138
# 3   İstanbul         Beykoz                         4953
# 4   İstanbul        Beyoğlu                         5931
# 5   İstanbul        Çatalca                          956
# 6   İstanbul     Eyüpsultan                         6263
# 7   İstanbul          Fatih                         8453
# 8   İstanbul  Gaziosmanpaşa                        10084
# 9   İstanbul        Kadıköy                         3051
# 10  İstanbul         Kartal                         8180
# 11  İstanbul        Sarıyer                         5205
# 12  İstanbul        Silivri                         2140
# 13  İstanbul           Şile                          720
# 14  İstanbul          Şişli                         4302
# ...

# %%
ogr.describe()
# Out:
#        okuma_yazma_bilmeyen_sayisi  okuma_yazma_bilip_okul_bitirmeyen  \
# count                    39.000000                          39.000000
# mean                   6609.230769                        8747.282051
# std                    4055.492140                        5865.024094
# min                     229.000000                         350.000000
# 25%                    3522.000000                        4268.000000
# 50%                    6263.000000                        8417.000000
# 75%                    8492.000000                       11326.500000
# max                   15727.000000                       25059.000000
#
#              ilkokul     ilköğretim      ortaokul           lise  \
# count      39.000000      39.000000     39.000000      39.000000
# mean    56931.692308   40410.384615  25012.512821   69739.564103
# std     30800.906032   28618.415250  13087.323211   35031.450831
# min      2248.000000     703.000000   1193.000000    3422.000000
# ...

# %% [markdown]
# I turned into numbers to percantages before I concencanete sec.csv with ogr.csv for get better results.

# %%
frames = [secim,ogr]
ogr[['okuma_yazma_bilmeyen_sayisi', 'okuma_yazma_bilip_okul_bitirmeyen', 'ilkokul', 'ilköğretim','ortaokul','lise','yüksekokul_veya_fakülte','yüksek_lisans','doktora','bilinmeyen']] = ogr[['okuma_yazma_bilmeyen_sayisi', 'okuma_yazma_bilip_okul_bitirmeyen', 'ilkokul', 'ilköğretim','ortaokul','lise','yüksekokul_veya_fakülte','yüksek_lisans','doktora','bilinmeyen']].apply(lambda x: x/x.sum(), axis=1)
secogr = pd.concat(frames,axis=1)

# %% [markdown]
# ## Explatory Data Analysis

# %% [markdown]
# We are going to look correlation Muharrem_İnce_oy_yüzdesi  between yüksekokul_veya_fakülte,yuksek_lisans,doktora columns
# and correlation Recep_Tayyip_Erdoğan_oy_yüzdesi between okuma_yazma_bilmeyen_sayisi,okuma_yazma_bilip_okul_bitirmeyen,ilkokul,ilköğretim,ortaokul columns to test my hypothesis.

# %%
print("correlation Muharrem_İnce_oy_yüzdesi between yüksekokul_veya_fakülte",secogr['Muharrem_İnce_oy_yüzdesi'].corr(secogr['yüksekokul_veya_fakülte']))
print("correlation Muharrem_İnce_oy_yüzdesi between yüksek_lisans",secogr['Muharrem_İnce_oy_yüzdesi'].corr(secogr['yüksek_lisans']))
print("correlation Muharrem_İnce_oy_yüzdesi between doktora",secogr['Muharrem_İnce_oy_yüzdesi'].corr(secogr['doktora']))

X = ['yüksekokul_veya_fakülte','yüksek_lisans','doktora']
y = [secogr['Muharrem_İnce_oy_yüzdesi'].corr(secogr['yüksekokul_veya_fakülte']),secogr['Muharrem_İnce_oy_yüzdesi'].corr(secogr['yüksek_lisans']),secogr['Muharrem_İnce_oy_yüzdesi'].corr(secogr['doktora'])]


X2 = ['okuma_yazma_bilmeyen_sayisi','okuma_yazma_bilip_okul_bitirmeyen','ilkokul','ilköğretim','ortaokul']
y2 = [secogr['Muharrem_İnce_oy_yüzdesi'].corr(secogr['okuma_yazma_bilmeyen_sayisi']),secogr['Muharrem_İnce_oy_yüzdesi'].corr(secogr['okuma_yazma_bilip_okul_bitirmeyen']),secogr['Muharrem_İnce_oy_yüzdesi'].corr(secogr['ilkokul']),secogr['Muharrem_İnce_oy_yüzdesi'].corr(secogr['ilköğretim']),secogr['Muharrem_İnce_oy_yüzdesi'].corr(secogr['ortaokul'])]


plt.figure(figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')
plt.subplot(2,2,1)
plt.title('Muharrem İnce percantage of vote correlation with  higher educational level table.')
plt.plot(X,y,'ro')
plt.ylabel('correlation values')
plt.xlabel('education level')
plt.show()

plt.figure(figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')
plt.subplot(2,2,2)
plt.title('Muharrem İnce percantage of vote correlation with lower educational level table.')
plt.plot(X2,y2,'ro')
plt.ylabel('correlation values')
plt.xlabel('education level')
plt.show()
# Out:
# correlation Muharrem_İnce_oy_yüzdesi between yüksekokul_veya_fakülte 0.8826814859243707
# correlation Muharrem_İnce_oy_yüzdesi between yüksek_lisans 0.8618292125726038
# correlation Muharrem_İnce_oy_yüzdesi between doktora 0.8436988274098325

# %% [markdown]
# We see the correlations above and this values is enough to say more educated people voted for Muharrem İnce.

# %%
print("correlation Recep_Tayyip_Erdoğan_oy_yüzdesi between okuma_yazma_bilmeyen_sayisi",secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['okuma_yazma_bilmeyen_sayisi']))
print("correlation Recep_Tayyip_Erdoğan_oy_yüzdesi between okuma_yazma_bilip_okul_bitirmeyen",secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['okuma_yazma_bilip_okul_bitirmeyen']))
print("correlation Recep_Tayyip_Erdoğan_oy_yüzdesi between ilkokul",secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['ilkokul']))
print("correlation Recep_Tayyip_Erdoğan_oy_yüzdesi between ilköğretim",secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['ilköğretim']))
print("correlation Recep_Tayyip_Erdoğan_oy_yüzdesi between ortaokul",secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['ortaokul']))


X = ['okuma_yazma_bilmeyen_sayisi','okuma_yazma_bilip_okul_bitirmeyen','ilkokul','ilköğretim','ortaokul']
y = [secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['okuma_yazma_bilmeyen_sayisi']),secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['okuma_yazma_bilip_okul_bitirmeyen']),secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['ilkokul']),secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['ilköğretim']),secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['ortaokul'])]
X2 = ['yüksekokul_veya_fakülte','yüksek_lisans','doktora']
y2 = [secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['yüksekokul_veya_fakülte']),secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['yüksek_lisans']),secogr['Recep_Tayip_Erdoğan_oy_yüzdesi'].corr(secogr['doktora'])]


plt.figure(figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')
plt.subplot(2,2,1)
plt.title('Recep Tayyip Erdoğan percantage of vote correlation with  lower educational level table.')
plt.plot(X,y,'ro')
plt.ylabel('correlation values')
plt.xlabel('education level')
plt.show()

plt.figure(figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')
plt.subplot(2,2,2)
plt.title('Recep Tayyip Erdoğan percantage of vote correlation with higher educational level table.')
plt.plot(X2,y2,'ro')
plt.ylabel('correlation values')
plt.xlabel('education level')
plt.show()
# Out:
# correlation Recep_Tayyip_Erdoğan_oy_yüzdesi between okuma_yazma_bilmeyen_sayisi 0.8121343893686345
# correlation Recep_Tayyip_Erdoğan_oy_yüzdesi between okuma_yazma_bilip_okul_bitirmeyen 0.6927212970165367
# correlation Recep_Tayyip_Erdoğan_oy_yüzdesi between ilkokul 0.6725268319242445
# correlation Recep_Tayyip_Erdoğan_oy_yüzdesi between ilköğretim 0.8113418755330131
# correlation Recep_Tayyip_Erdoğan_oy_yüzdesi between ortaokul 0.6961883753080159

# %% [markdown]
# We see the correlations above and this values is enough to say less educated people voted for Recep Tayyip Erdoğan

# %% [markdown]
# And if you want to full correlation table you can see below.

# %%
secogr.corr()
# Out:
#                                    Sandık_Sayısı  Kayıtlı_SeçmenSayısı  \
# Sandık_Sayısı                           1.000000              0.999537
# Kayıtlı_SeçmenSayısı                    0.999537              1.000000
# Oy_Kullanan_Seçmen_Sayısı               0.999155              0.999438
# Katılım_Yüzdesi                        -0.274807             -0.288017
# Geçerli_oy_sayısı                       0.999127              0.999404
# Geçerli_oy_sayı_yüzdesi                 0.161756              0.165708
# Muharrem_İnce_oy_sayısı                 0.762670              0.758033
# Muharrem_İnce_oy_yüzdesi               -0.233504             -0.238768
# Meral_Akşaner_oy_sayısı                 0.922291              0.918592
# Meral_Akşener_oy_yüzdesi               -0.352929             -0.364738
# Recep_Tayyip_Erdoğan_oy_sayısı          0.916840              0.919971
# Recep_Tayip_Erdoğan_oy_yüzdesi          0.233726              0.238785
# ...

# %%
plt.figure(num=None, figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')
sandik5 = secim.sort_values(by='Sandık_Sayısı',ascending=0)[:5]
m = sandik5['Muharrem_İnce_oy_sayısı']
ak = sandik5['Meral_Akşaner_oy_sayısı']
rte = sandik5['Recep_Tayyip_Erdoğan_oy_sayısı']

y_pos = np.arange(len(sandik5.İlçe.values))

plt.xticks(y_pos, sandik5.İlçe.values)

plt.bar(y_pos-0.25 , rte, color = 'orange', width = 0.25)
plt.bar(y_pos, m, color = 'b', width = 0.25)
plt.bar(y_pos+0.25 , ak, color = 'g', width = 0.25)
plt.title('5 county with the most ballot boxes and results for this county\'s')
plt.ylabel('Vote count')
plt.xlabel('5 county with the most ballot')

barnames= ['Recep_Tayyip_Erdoğan_oy_sayısı','Muharrem_İnce_oy_sayısı','Meral_Akşaner_oy_sayısı']
plt.legend(barnames,loc=2)

plt.show()

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# I used three different algoritm for regression. First one is Linear Regression , second one is KNN regression , and last one is Neural Network Regressor. My goal is getting mean squared error less than 0.25

# %%
X = secogr[['okuma_yazma_bilmeyen_sayisi', 'okuma_yazma_bilip_okul_bitirmeyen', 'ilkokul', 'ilköğretim','ortaokul','lise','yüksekokul_veya_fakülte','yüksek_lisans','doktora','bilinmeyen']] 
y = secogr[['Recep_Tayip_Erdoğan_oy_yüzdesi','Muharrem_İnce_oy_yüzdesi','Meral_Akşener_oy_yüzdesi']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
import pickle
loaded_linear = pickle.load(open('data/linearsec.sav', 'rb'))
# Out:
# /home/mert/anaconda3/envs/tensorflow_gpu/lib/python3.6/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LinearRegression from version 0.20.3 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
y_pred = loaded_linear.predict(X_test)
test_error_linear = mean_squared_error(y_test,y_pred)
print(test_error_linear)
# Out:
# 21.78962301114251

# %% [markdown]
# Linear Regression mean squared error is less than 0.25 , this is verify my hypothesis. (Proof 1)

# %%
print("Predicted values : \n",y_pred)
print("Actual values : \n", np.array(y_test))

countys = ['Başakşehir', 'Esenyurt', 'Beyoğlu', 'Şile', 'Esenler', 'Güngören','Eyüpsultan', 'Maltepe', 'Bağcılar', 'Üsküdar']
plt.figure(num=None, figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')


y_pos = np.arange(len(countys))
truelabels = np.array(y_test)
plt.xticks(y_pos, countys)

line1 = plt.bar(y_pos-0.47 , truelabels[:,0], color = 'black', width = 0.15 , label='label1')
line2 =plt.bar(y_pos-0.32 , y_pred[:,0], color = 'orange', width = 0.15 , label='label2')
plt.bar(y_pos-0.15, truelabels[:,1], color = 'black', width = 0.15 )
line3 = plt.bar(y_pos, y_pred[:,1], color = 'b', width = 0.15, label='label3')
plt.bar(y_pos+0.17 , truelabels[:,2], color = 'black', width = 0.15)
line4 = plt.bar(y_pos+0.32 , y_pred[:,2], color = 'g', width = 0.15 , label='label4')
plt.title('Linear Regression predicts table')
plt.ylabel('Vote percentage(%)')
plt.xlabel('Countys')


plt.legend([line1, line2,line3,line4],barnames,loc=2)
plt.show()
# Out:
# Predicted values :
#  [[46.01152775 40.37577579  4.24329681]
#  [57.773031   24.60930729  3.29553925]
#  [52.05256551 33.3429743   3.83526647]
#  [46.69581767 42.15706167  9.00012761]
#  [62.29058646 22.04872199  4.5717778 ]
#  [54.61804576 32.45203228  5.68570975]
#  [52.46616668 36.53035763  5.52305546]
#  [40.93595    48.22405778  5.29833754]
#  [61.92655741 21.43635118  3.6455183 ]
#  [41.29203256 49.14489109  5.64402593]]
# Actual values :
#  [[54.7 28.8  4.8]
#  [47.6 31.3  3.6]
#  [52.2 32.2  3.9]
#  [53.  33.5  8.9]
#  [66.9 18.9  4. ]
#  [55.6 30.3  5. ]
#  [50.8 39.3  4.7]
#  [40.3 50.5  4.7]
#  [61.3 21.4  4. ]
#  [48.8 40.9  5.8]]

# %%
loaded_knn = pickle.load(open('data/knnsec.sav', 'rb'))
y_predKNN = loaded_knn.predict(X_test)
test_error_KNN = mean_squared_error(y_test,y_predKNN)
print(test_error_KNN)
# Out:
# 18.025444444444457
# /home/mert/anaconda3/envs/tensorflow_gpu/lib/python3.6/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator KNeighborsRegressor from version 0.20.3 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
print("Predicted values : \n",y_predKNN)
print("Actual values : \n", np.array(y_test))



plt.figure(num=None, figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')

y_pos = np.arange(len(countys))
truelabels = np.array(y_test)
plt.xticks(y_pos, countys)

line1 = plt.bar(y_pos-0.47 , truelabels[:,0], color = 'black', width = 0.15 , label='label1')
line2 =plt.bar(y_pos-0.32 , y_predKNN[:,0], color = 'orange', width = 0.15 , label='label2')
plt.bar(y_pos-0.15, truelabels[:,1], color = 'black', width = 0.15 )
line3 = plt.bar(y_pos, y_predKNN[:,1], color = 'b', width = 0.15, label='label3')
plt.bar(y_pos+0.17 , truelabels[:,2], color = 'black', width = 0.15)
line4 = plt.bar(y_pos+0.32 , y_predKNN[:,2], color = 'g', width = 0.15 , label='label4')
plt.title('KNN predicts table')
plt.ylabel('Vote percentage(%)')
plt.xlabel('Countys')


plt.legend([line1, line2,line3,line4],barnames,loc=2)
plt.show()
# Out:
# Predicted values :
#  [[53.93333333 34.26666667  5.36666667]
#  [54.43333333 29.56666667  4.46666667]
#  [55.83333333 30.4         5.4       ]
#  [45.76666667 40.76666667  7.36666667]
#  [65.4        17.          3.3       ]
#  [55.83333333 33.73333333  5.46666667]
#  [54.6        33.5         5.1       ]
#  [39.06666667 51.36666667  4.33333333]
#  [57.36666667 27.9         3.63333333]
#  [39.06666667 51.36666667  4.33333333]]
# Actual values :
#  [[54.7 28.8  4.8]
#  [47.6 31.3  3.6]
#  [52.2 32.2  3.9]
#  [53.  33.5  8.9]
#  [66.9 18.9  4. ]
#  [55.6 30.3  5. ]
#  [50.8 39.3  4.7]
#  [40.3 50.5  4.7]
#  [61.3 21.4  4. ]
#  [48.8 40.9  5.8]]

# %% [markdown]
# KNN Regression mean squared error is less than 0.25 , this is verify my hypothesis. (Proof 2)

# %%
loaded_NN = pickle.load(open('data/nnsec.sav', 'rb'))
y_predNN = loaded_NN.predict(X_test)
test_error_NN = mean_squared_error(y_test,y_predNN)
print(test_error_NN)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/mert/anaconda3/envs/tensorflow_gpu/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/mert/anaconda3/envs/tensorflow_gpu/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 17.184274940331616

# %%
print("Predicted values : \n",y_predNN)
print("Actual values : \n", np.array(y_test))

plt.figure(num=None, figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')

y_pos = np.arange(len(countys))
truelabels = np.array(y_test)
plt.xticks(y_pos, countys)

line1 = plt.bar(y_pos-0.47 , truelabels[:,0], color = 'black', width = 0.15 , label='label1')
line2 =plt.bar(y_pos-0.32 , y_predNN[:,0], color = 'orange', width = 0.15 , label='label2')
plt.bar(y_pos-0.15, truelabels[:,1], color = 'black', width = 0.15 )
line3 = plt.bar(y_pos, y_predNN[:,1], color = 'b', width = 0.15, label='label3')
plt.bar(y_pos+0.17 , truelabels[:,2], color = 'black', width = 0.15)
line4 = plt.bar(y_pos+0.32 , y_predNN[:,2], color = 'g', width = 0.15 , label='label4')
plt.title('NN predicts table')
plt.ylabel('Vote percentage(%)')
plt.xlabel('Countys')


plt.legend([line1, line2,line3,line4],barnames,loc=2)
plt.show()
# Out:
# Predicted values :
#  [[47.509003  40.077736   5.178869 ]
#  [55.624706  27.622555   4.7902703]
#  [53.800026  31.25761    5.0777354]
#  [50.32046   37.546738   6.804522 ]
#  [59.16817   24.180752   4.9676223]
#  [55.0283    32.033333   4.773232 ]
#  [51.596542  36.63338    5.2948537]
#  [42.12559   47.71898    5.296244 ]
#  [58.505245  24.636782   4.631838 ]
#  [42.265656  48.042137   5.117424 ]]
# Actual values :
#  [[54.7 28.8  4.8]
#  [47.6 31.3  3.6]
#  [52.2 32.2  3.9]
#  [53.  33.5  8.9]
#  [66.9 18.9  4. ]
#  [55.6 30.3  5. ]
#  [50.8 39.3  4.7]
#  [40.3 50.5  4.7]
#  [61.3 21.4  4. ]
#  [48.8 40.9  5.8]]

# %% [markdown]
# Neural Network Regression mean squared error is less than 0.25 , this is verify my hypothesis. (Proof 3)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
projected = pca.fit_transform(X)

# %%
print(pca.components_)
# Out:
# [[-0.05874436 -0.08806271 -0.45495052 -0.47253856 -0.06493196  0.20270273
#    0.69272446  0.17505086  0.0474817   0.02126835]
#  [-0.04009668 -0.06804515  0.69923977 -0.69896224  0.0430588   0.10035648
#   -0.0505348  -0.02208621  0.00087856  0.03619148]]

# %%
print(pca.mean_)
# Out:
# [0.02372746 0.03143603 0.21495314 0.14242559 0.09204749 0.25802663
#  0.1970493  0.02552746 0.0053683  0.0094386 ]

# %%
x_38_reconstructed = pca.mean_+ projected[38].dot(pca.components_)
print(x_38_reconstructed)
X[38:]
# Out:
# [ 0.03374788  0.04653443  0.282767    0.22667924  0.1022762   0.2238187
#   0.08396082 -0.00295958 -0.00242527  0.00560058]
#     okuma_yazma_bilmeyen_sayisi  okuma_yazma_bilip_okul_bitirmeyen  ilkokul  \
# 38                     0.035572                           0.051215  0.28576
#
#     ilköğretim  ortaokul      lise  yüksekokul_veya_fakülte  yüksek_lisans  \
# 38    0.225162  0.098351  0.201868                 0.089492       0.004729
#
#      doktora  bilinmeyen
# 38  0.000691    0.007161

# %% [markdown]
# As we see we can get very close results so that if we want to make dimension reduction we can make 2 components PCA

# %%
result = X_test.join(secim,how='inner')

# %%
result2 = result[['İl','İlçe']]

# %%
pd.set_option('mode.chained_assignment', None)
result2['Recep_Tayip_Erdoğan_oy_yüzdesi'] = result['Recep_Tayip_Erdoğan_oy_yüzdesi']
result2['Predicted_Linear_Recep'] = y_pred[:,0]
result2['Predicted_KNN_Recep'] = y_predKNN[:,0]
result2['Predicted_NN_Recep'] = y_predNN[:,0]

result2['Muharrem_İnce_oy_yüzdesi'] = result['Muharrem_İnce_oy_yüzdesi']
result2['Predicted_Linear_İnce'] = y_pred[:,1] 
result2['Predicted_KNN_İnce'] = y_predKNN[:,1]
result2['Predicted_NN_İnce'] = y_predNN[:,1]


result2['Meral_Akşener_oy_yüzdesi'] = result['Meral_Akşener_oy_yüzdesi']
result2['Predicted_Linear_Akşener'] = y_pred[:,2] 
result2['Predicted_KNN_Akşener'] = y_predKNN[:,2]
result2['Predicted_NN_Akşener'] = y_predNN[:,2]

# %%
new_order = ['İl','İlçe','Recep_Tayip_Erdoğan_oy_yüzdesi','Predicted_Linear_Recep','Predicted_KNN_Recep','Predicted_NN_Recep','Muharrem_İnce_oy_yüzdesi','Predicted_Linear_İnce','Predicted_KNN_İnce','Predicted_NN_İnce','Meral_Akşener_oy_yüzdesi','Predicted_Linear_Akşener','Predicted_KNN_Akşener','Predicted_NN_Akşener']
result2 = result2.reindex(columns=new_order)

# %% [markdown]
# ## Conclusion

# %%
result2
# Out:
#           İl        İlçe  Recep_Tayip_Erdoğan_oy_yüzdesi  \
# 33  İstanbul  Başakşehir                            54.7
# 36  İstanbul    Esenyurt                            47.6
# 4   İstanbul     Beyoğlu                            52.2
# 13  İstanbul        Şile                            53.0
# 30  İstanbul     Esenler                            66.9
# 26  İstanbul    Güngören                            55.6
# 6   İstanbul  Eyüpsultan                            50.8
# 27  İstanbul     Maltepe                            40.3
# 24  İstanbul    Bağcılar                            61.3
# 15  İstanbul     Üsküdar                            48.8
#
#     Predicted_Linear_Recep  Predicted_KNN_Recep  Predicted_NN_Recep  \
# 33               46.011528            53.933333           47.509003
# 36               57.773031            54.433333           55.624706
# 4                52.052566            55.833333           53.800026
# ...

# %%
plt.figure(num=None, figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')
plt.plot(result2['İlçe'],result2['Recep_Tayip_Erdoğan_oy_yüzdesi'] , 'ro')
plt.plot(result2['İlçe'],result2['Predicted_Linear_Recep'] , '+')
plt.plot(result2['İlçe'],result2['Predicted_KNN_Recep'] , 'x')
plt.plot(result2['İlçe'],result2['Predicted_NN_Recep'] , 'g^')
plt.title('Table of all predictions about Recep_Tayip_Erdoğan_oy_yüzdesi.')
plt.xlabel('Countys')
plt.ylabel('Percantage of vote(%)')
barnames= ['Recep_Tayip_Erdoğan_oy_yüzdesi','Predicted_Linear_Recep','Predicted_KNN_Recep','Predicted_NN_Recep']
plt.legend(barnames,loc=2)

# %%
plt.figure(num=None, figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')
plt.plot(result2['İlçe'],result2['Muharrem_İnce_oy_yüzdesi'] , 'ro')
plt.plot(result2['İlçe'],result2['Predicted_Linear_İnce'] , '+')
plt.plot(result2['İlçe'],result2['Predicted_KNN_İnce'] , 'x')
plt.plot(result2['İlçe'],result2['Predicted_NN_İnce'] , 'g^')
plt.title('Table of all predictions about Muharrem_İnce_oy_yüzdesi.')
plt.xlabel('Countys')
plt.ylabel('Percantage of vote(%)')
barnames= ['Muharrem_İnce_oy_yüzdesi','Predicted_Linear_İnce','Predicted_KNN_İnce','Predicted_NN_İnce']
plt.legend(barnames,loc=2)

# %%
plt.figure(num=None, figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')
plt.plot(result2['İlçe'],result2['Meral_Akşener_oy_yüzdesi'] , 'ro')
plt.plot(result2['İlçe'],result2['Predicted_Linear_Akşener'] , '+')
plt.plot(result2['İlçe'],result2['Predicted_KNN_Akşener'] , 'x')
plt.plot(result2['İlçe'],result2['Predicted_NN_Akşener'] , 'g^')
plt.title('Table of all predictions about Muharrem_İnce_oy_yüzdesi.')
plt.xlabel('Countys')
plt.ylabel('Percantage of vote(%)')
barnames= ['Meral_Akşener_oy_yüzdesi','Predicted_Linear_Akşener','Predicted_KNN_Akşener','Predicted_NN_Akşener']
plt.legend(barnames,loc=2)

# %% [markdown]
# This tables represents the whole of my predictions. (Linear,KNN,Neural Network)

# %%
print('Linear Regression mean square error = ' ,test_error_linear)
print('KNN Regression mean square error = ' ,test_error_KNN)
print('Neural Network Regression mean square error = ' ,test_error_NN)
# Out:
# Linear Regression mean square error =  21.78962301114251
# KNN Regression mean square error =  18.025444444444457
# Neural Network Regression mean square error =  17.184274940331616

# %% [markdown]
# I use 3 neighbor for KNN and Neural Network Regression I did 1000 epochs with 0.2 validate. There were  one input(256) , three hidden(512), one output layer (3). And I get closest regressions with Neural Network Regression. My machine learning hypothesis was  mean squared error of my predictions will be less than 0.25 and you can see the results above. This results proves my hypothesis.

# %% [markdown]
# My statistical hypothesis was more educated people voting Muharrem İnce. If we look up to cell(6) and cell(7) we can prove that hypothesis with these correlation statistics.

# %% [markdown]
# Since the estimation of the votes is not only about education, I can get closer to the real values by adding each statistic that affects the votes. I've tried a few parameters for regressions, but I couldn't have tried a better result. But there may be better parameters for regression which I could not find.
